# %%
'''
My Attempt at the Hilbert CNN at https://openreview.net/forum?id=HJvvRoe0W
Works by dividing the sequence into a series of overlapping 4-mers, 
then fits it to a image-like grid using a hilbert curve
such that each 'pixel' is a 4mer of length 256 (4**4=256)
'''

# %%
from keras.layers import Conv2D, BatchNormalization, AveragePooling2D, Dense, Dropout
from keras.layers import Activation, Input, Concatenate, Flatten, MaxPooling2D
from keras.models import Model
from keras.optimizers import RMSprop
from keras.callbacks import ReduceLROnPlateau, ModelCheckpoint, CSVLogger, LearningRateScheduler
import image
from keras import backend as K
import numpy as np
# Out:
# c:\users\wolfgang\anaconda3\envs\tensorflow\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
start_target_size = (32, 32, 256)
batch_size = 16
train_path = 'D:/Projects/iSynPro/iSynPro/HilbertCNN/train_val_npys/train'
test_path = 'D:/Projects/iSynPro/iSynPro/HilbertCNN/train_val_npys/test'

# define generators
train_datagen = image.ImageDataGenerator()
test_datagen = image.ImageDataGenerator()

train_generator = train_datagen.flow_np_from_directory(train_path, 
                                                    target_size= start_target_size, 
                                                    batch_size=batch_size, 
                                                    class_mode='binary',
                                                    seed=42) 

validation_generator = test_datagen.flow_np_from_directory(test_path, 
                                                        target_size= start_target_size, 
                                                        batch_size=batch_size, 
                                                        class_mode='binary',
                                                        seed=42)
# Out:
# Found 17591 images belonging to 2 classes.
# Found 1955 images belonging to 2 classes.

# %%
preview  = []
p = np.load('D:/Projects/iSynPro/iSynPro/HilbertCNN/train_val_npys/train/high/2.npy')
i = 0
for batch in train_datagen.flow_np_from_directory(p, 
                                                    target_size= start_target_size, 
                                                    batch_size= 1, 
                                                    save_to_dir='../',
                                                  save_prefix='preview') :
    i += 1
    if 1 > 1:
        break
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-47-e8d043394ddd> in <module>()
#       6                                                     batch_size= 1,
#       7                                                     save_to_dir='../',
# ----> 8                                                   save_prefix='preview') :
#       9     i += 1
#      10     if 1 > 1:
#
# D:\Projects\iSynPro\iSynPro\HilbertCNN\image.py in flow_np_from_directory(self, directory, target_size, color_mode, classes, class_mode, batch_size, shuffle, seed, save_to_dir, save_prefix, save_format)
#     314             dim_ordering=self.dim_ordering,
#     315             batch_size=batch_size, shuffle=shuffle, seed=seed,
# --> 316             save_to_dir=save_to_dir, save_prefix=save_prefix, save_format=save_format)
#     317
#     318     def standardize(self, x):
#
# D:\Projects\iSynPro\iSynPro\HilbertCNN\image.py in __init__(self, directory, image_data_generator, target_size, color_mode, dim_ordering, classes, class_mode, batch_size, shuffle, seed, save_to_dir, save_prefix, save_format)
#     742         if not classes:
#     743             classes = []
# --> 744             for subdir in sorted(os.listdir(directory)):
#     745                 if os.path.isdir(os.path.join(directory, subdir)):
#     746                     classes.append(subdir)
#
# ValueError: listdir: path too long for Windows

# %%
###Only call this if you want to clear the model, so you can train a new one
K.clear_session()
del model

# %%
# modified implementation of Hilbert-CNN
# wider and shallower than original
# https://openreview.net/forum?id=HJvvRoe0W
# 

inputs = Input(shape=[32, 32, 256])

# stem
x = Conv2D(64, (7, 7), strides=(1, 1), padding='same')(inputs)
x = BatchNormalization()(x)
x = Conv2D(64, (5, 5), strides=(1, 1), padding='same')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = MaxPooling2D(pool_size=(2, 2), strides=(2, 2))(x)

# computation block1
# residual 1
p1 = Conv2D(4, (8, 8), strides=(1, 1), padding='same')(x)
p1 = BatchNormalization()(p1)
p1 = Activation('relu')(p1)
p1 = Conv2D(4, (4, 4), strides=(1, 1), padding='same')(p1)
p1 = BatchNormalization()(p1)

# residual 2
p2 = Conv2D(4, (4, 4), strides=(1, 1), padding='same')(x)
p2 = BatchNormalization()(p2)
p2 = Activation('relu')(p2)
p2 = Conv2D(4, (3, 3), strides=(1, 1), padding='same')(p2)
p2 = BatchNormalization()(p2)

x = Concatenate()([x, p1, p2])
x = BatchNormalization()(x)
x = Activation('relu')(x)

# computation block2
# residual 1
p1 = Conv2D(4, (8, 8), strides=(1, 1), padding='same')(x)
p1 = BatchNormalization()(p1)
p1 = Activation('relu')(p1)
p1 = Conv2D(4, (4, 4), strides=(1, 1), padding='same')(p1)
p1 = BatchNormalization()(p1)

# residual 2
p2 = Conv2D(4, (4, 4), strides=(1, 1), padding='same')(x)
p2 = BatchNormalization()(p2)
p2 = Activation('relu')(p2)
p2 = Conv2D(4, (3, 3), strides=(1, 1), padding='same')(p2)
p2 = BatchNormalization()(p2)

x = Concatenate()([x, p1, p2])
x = BatchNormalization()(x)
x = Activation('relu')(x)

# mid-stem
x = MaxPooling2D(pool_size=(2, 2), strides=(2, 2))(x)

# computation block 3
# residual 1
p1 = Conv2D(4, (8, 8), strides=(1, 1), padding='same')(x)
p1 = BatchNormalization()(p1)
p1 = Activation('relu')(p1)
p1 = Conv2D(4, (4, 4), strides=(1, 1), padding='same')(p1)
p1 = BatchNormalization()(p1)

# residual 2
p2 = Conv2D(4, (4, 4), strides=(1, 1), padding='same')(x)
p2 = BatchNormalization()(p2)
p2 = Activation('relu')(p2)
p2 = Conv2D(4, (3, 3), strides=(1, 1), padding='same')(p2)
p2 = BatchNormalization()(p2)

x = Concatenate()([x, p1, p2])
x = BatchNormalization()(x)
x = Activation('relu')(x)
'''
# computation block 4
# residual 1
p1 = Conv2D(4, (2, 2), strides=(1, 1), padding='same')(x)
p1 = BatchNormalization()(p1)
p1 = Activation('relu')(p1)
p1 = Conv2D(4, (2, 2), strides=(1, 1), padding='same')(p1)
p1 = BatchNormalization()(p1)

# residual 2
p2 = Conv2D(4, (2, 2), strides=(1, 1), padding='same')(x)
p2 = BatchNormalization()(p2)
p2 = Activation('relu')(p2)
p2 = Conv2D(4, (2, 2), strides=(1, 1), padding='same')(p2)
p2 = BatchNormalization()(p2)

x = Concatenate()([x, p1, p2])
x = BatchNormalization()(x)
x = Activation('relu')(x)

# computation block 5
# residual 1
p1 = Conv2D(4, (3, 3), strides=(1, 1), padding='same')(x)
p1 = BatchNormalization()(p1)
p1 = Activation('relu')(p1)
p1 = Conv2D(4, (2, 2), strides=(1, 1), padding='same')(p1)
p1 = BatchNormalization()(p1)

# residual 2
p2 = Conv2D(4, (2, 2), strides=(1, 1), padding='same')(x)
p2 = BatchNormalization()(p2)
p2 = Activation('relu')(p2)
p2 = Conv2D(4, (3, 3), strides=(1, 1), padding='same')(p2)
p2 = BatchNormalization()(p2)

x = Concatenate()([x, p1, p2])
x = BatchNormalization()(x)
x = Activation('relu')(x)
'''
# exit stem
x = MaxPooling2D(pool_size=(2, 2), strides=(2, 2))(x)
#x = BatchNormalization()(x)
#x = Activation('relu')(x)
#x = AveragePooling2D(pool_size=(2, 2), strides=(2, 2))(x) #we omit this last avgpool to retain dimensionality
x = Flatten()(x)

# FC layers
x = Dense(1024)(x)
x = Activation('relu')(x)
#x = Dropout(0.1)(x)

x = Dense(1024)(x)
x = Activation('relu')(x)
#x = Dropout(0.1)(x)

predictions = Dense(1, activation='sigmoid')(x)

model = Model(inputs=inputs, outputs=predictions)

model.compile(optimizer= RMSprop(),
              loss= 'binary_crossentropy',
              metrics=[ 'binary_accuracy'])

# %%
# original implementation of Hilbert-CNN
# https://openreview.net/forum?id=HJvvRoe0W

inputs = Input(shape=[32, 32, 256])

# stem
x = Conv2D(64, (7, 7), strides=(1, 1), padding='same')(inputs)
x = BatchNormalization()(x)
x = Conv2D(64, (5, 5), strides=(1, 1), padding='same')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = AveragePooling2D(pool_size=(2, 2), strides=(2, 2))(x)

# computation block1
# residual 1
p1 = Conv2D(4, (8, 8), strides=(1, 1), padding='same')(x)
p1 = BatchNormalization()(p1)
p1 = Activation('relu')(p1)
p1 = Conv2D(4, (4, 4), strides=(1, 1), padding='same')(p1)
p1 = BatchNormalization()(p1)

# residual 2
p2 = Conv2D(4, (4, 4), strides=(1, 1), padding='same')(x)
p2 = BatchNormalization()(p2)
p2 = Activation('relu')(p2)
p2 = Conv2D(4, (3, 3), strides=(1, 1), padding='same')(p2)
p2 = BatchNormalization()(p2)

x = Concatenate()([x, p1, p2])
x = BatchNormalization()(x)
x = Activation('relu')(x)

# computation block 2
# residual 1
p1 = Conv2D(4, (3, 3), strides=(1, 1), padding='same')(x)
p1 = BatchNormalization()(p1)
p1 = Activation('relu')(p1)
p1 = Conv2D(4, (3, 3), strides=(1, 1), padding='same')(p1)
p1 = BatchNormalization()(p1)

# residual 2
p2 = Conv2D(4, (3, 3), strides=(1, 1), padding='same')(x)
p2 = BatchNormalization()(p2)
p2 = Activation('relu')(p2)
p2 = Conv2D(4, (3, 3), strides=(1, 1), padding='same')(p2)
p2 = BatchNormalization()(p2)

x = Concatenate()([x, p1, p2])
x = BatchNormalization()(x)
x = Activation('relu')(x)

# mid-stem
x = AveragePooling2D(pool_size=(2, 2), strides=(2, 2))(x)

# computation block 3
# residual 1
p1 = Conv2D(4, (2, 2), strides=(1, 1), padding='same')(x)
p1 = BatchNormalization()(p1)
p1 = Activation('relu')(p1)
p1 = Conv2D(4, (4, 4), strides=(1, 1), padding='same')(p1)
p1 = BatchNormalization()(p1)

# residual 2
p2 = Conv2D(4, (4, 4), strides=(1, 1), padding='same')(x)
p2 = BatchNormalization()(p2)
p2 = Activation('relu')(p2)
p2 = Conv2D(4, (3, 3), strides=(1, 1), padding='same')(p2)
p2 = BatchNormalization()(p2)

x = Concatenate()([x, p1, p2])
x = BatchNormalization()(x)
x = Activation('relu')(x)

# computation block 4
# residual 1
p1 = Conv2D(4, (2, 2), strides=(1, 1), padding='same')(x)
p1 = BatchNormalization()(p1)
p1 = Activation('relu')(p1)
p1 = Conv2D(4, (2, 2), strides=(1, 1), padding='same')(p1)
p1 = BatchNormalization()(p1)

# residual 2
p2 = Conv2D(4, (2, 2), strides=(1, 1), padding='same')(x)
p2 = BatchNormalization()(p2)
p2 = Activation('relu')(p2)
p2 = Conv2D(4, (2, 2), strides=(1, 1), padding='same')(p2)
p2 = BatchNormalization()(p2)

x = Concatenate()([x, p1, p2])
x = BatchNormalization()(x)
x = Activation('relu')(x)

# computation block 5
# residual 1
p1 = Conv2D(4, (3, 3), strides=(1, 1), padding='same')(x)
p1 = BatchNormalization()(p1)
p1 = Activation('relu')(p1)
p1 = Conv2D(4, (2, 2), strides=(1, 1), padding='same')(p1)
p1 = BatchNormalization()(p1)

# residual 2
p2 = Conv2D(4, (2, 2), strides=(1, 1), padding='same')(x)
p2 = BatchNormalization()(p2)
p2 = Activation('relu')(p2)
p2 = Conv2D(4, (3, 3), strides=(1, 1), padding='same')(p2)
p2 = BatchNormalization()(p2)

x = Concatenate()([x, p1, p2])
x = BatchNormalization()(x)
x = Activation('relu')(x)

# exit stem
x = AveragePooling2D(pool_size=(2, 2), strides=(2, 2))(x)
#x = BatchNormalization()(x)
#x = Activation('relu')(x)
#x = AveragePooling2D(pool_size=(2, 2), strides=(2, 2))(x) #we omit this last avgpool to retain dimensionality
x = Flatten()(x)

# FC layers
x = Dense(1024)(x)
x = Activation('relu')(x)
#x = Dropout(0.1)(x)

x = Dense(1024)(x)
x = Activation('relu')(x)
#x = Dropout(0.1)(x)

predictions = Dense(1, activation='sigmoid')(x)

model = Model(inputs=inputs, outputs=predictions)

model.compile(optimizer= RMSprop(),
              loss= 'binary_crossentropy',
              metrics=[ 'binary_accuracy'])

# %%
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 32, 32, 256)  0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 32, 32, 64)   802880      input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 32, 32, 64)   256         conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 32, 32, 64)   102464      batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 32, 32, 64)   256         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 32, 32, 64)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 16, 16, 64)   0           activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 16, 16, 4)    16388       average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 16, 16, 4)    4100        average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 16, 16, 4)    16          conv2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 16, 16, 4)    16          conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 16, 16, 4)    0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 16, 16, 4)    0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 16, 16, 4)    260         activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 16, 16, 4)    148         activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 16, 16, 4)    16          conv2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 16, 16, 4)    16          conv2d_6[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 16, 16, 72)   0           average_pooling2d_1[0][0]
#                                                                  batch_normalization_4[0][0]
#                                                                  batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 16, 16, 72)   288         concatenate_1[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 16, 16, 72)   0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 16, 16, 4)    2596        activation_4[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 16, 16, 4)    2596        activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 16, 16, 4)    16          conv2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 16, 16, 4)    16          conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 16, 16, 4)    0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 16, 16, 4)    0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 16, 16, 4)    148         activation_5[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 16, 16, 4)    148         activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 16, 16, 4)    16          conv2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 16, 16, 4)    16          conv2d_10[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 16, 16, 80)   0           activation_4[0][0]
#                                                                  batch_normalization_9[0][0]
#                                                                  batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 16, 16, 80)   320         concatenate_2[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 16, 16, 80)   0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_2 (AveragePoo (None, 8, 8, 80)     0           activation_7[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 8, 8, 4)      1284        average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 8, 8, 4)      5124        average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 8, 8, 4)      16          conv2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 8, 8, 4)      16          conv2d_13[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 8, 8, 4)      0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 8, 8, 4)      0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 8, 8, 4)      260         activation_8[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 8, 8, 4)      148         activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 8, 8, 4)      16          conv2d_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 8, 8, 4)      16          conv2d_14[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 8, 8, 88)     0           average_pooling2d_2[0][0]
#                                                                  batch_normalization_14[0][0]
#                                                                  batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 8, 8, 88)     352         concatenate_3[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 8, 8, 88)     0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 8, 8, 4)      1412        activation_10[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 8, 8, 4)      1412        activation_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 8, 8, 4)      16          conv2d_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 8, 8, 4)      16          conv2d_17[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 8, 8, 4)      0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 8, 8, 4)      0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 8, 8, 4)      68          activation_11[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 8, 8, 4)      68          activation_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 8, 8, 4)      16          conv2d_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 8, 8, 4)      16          conv2d_18[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 8, 8, 96)     0           activation_10[0][0]
#                                                                  batch_normalization_19[0][0]
#                                                                  batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 8, 8, 96)     384         concatenate_4[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 8, 8, 96)     0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 8, 8, 4)      3460        activation_13[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 8, 8, 4)      1540        activation_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 8, 8, 4)      16          conv2d_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 8, 8, 4)      16          conv2d_21[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 8, 8, 4)      0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 8, 8, 4)      0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 8, 8, 4)      68          activation_14[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 8, 8, 4)      148         activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 8, 8, 4)      16          conv2d_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 8, 8, 4)      16          conv2d_22[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 8, 8, 104)    0           activation_13[0][0]
#                                                                  batch_normalization_24[0][0]
#                                                                  batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 8, 8, 104)    416         concatenate_5[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 8, 8, 104)    0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_3 (AveragePoo (None, 4, 4, 104)    0           activation_16[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 1664)         0           average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1024)         1704960     flatten_1[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 1024)         0           dense_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1024)         1049600     activation_17[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 1024)         0           dense_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 1)            1025        activation_18[0][0]
# ==================================================================================================
# Total params: 3,704,897
# Trainable params: 3,703,601
# Non-trainable params: 1,296
# __________________________________________________________________________________________________

# %%
train_size = 17591
test_size = 1955
learning_decay = 0.96 #not used
batch_size = 16


#our callbacks
lr_descent = ReduceLROnPlateau(monitor='val_loss',
                                               factor=0.5,
                                               patience=5,
                                               verbose=1,
                                               mode='auto',
                                               epsilon=0.0001,
                                               cooldown=1,
                                               min_lr=0)

save_model = ModelCheckpoint('D:/Projects/iSynPro/iSynPro/HilbertCNN/weights/weights-{epoch:02d}-{val_loss:.2f}.hdf5',
                                             monitor='val_loss',
                                             verbose=1, 
                                             save_best_only=True,
                                             save_weights_only=False,
                                             mode='auto',
                                             period=1)

csv_path = 'D:/Projects/iSynPro/iSynPro/HilbertCNN/weights/training_history.csv'
csv_logger = CSVLogger(csv_path, separator=',', append=False)

def incep_resnet_schedule(epoch):
    if epoch % 2 == 0:
        return 0.045*(0.96**(epoch))
    else:
        return 0.045*(0.96**((epoch)-1.0))

lr_scheduler = LearningRateScheduler(incep_resnet_schedule)

#tracking = keras.callbacks.ProgbarLogger(count_mode='samples')

#train the model
print('Beginning Training for 100 Epochs...')
model.fit_generator(train_generator, 
                                   steps_per_epoch= train_size // batch_size,
                                   epochs=100, 
                                   validation_data= validation_generator, 
                                   validation_steps= test_size // batch_size,
                                   verbose=2,
                                   callbacks = [save_model, csv_logger])
# Out:
# Beginning Training for 100 Epochs...
# Epoch 1/100
#
# Epoch 00001: val_loss improved from inf to 0.54609, saving model to D:/Projects/iSynPro/iSynPro/HilbertCNN/weights/weights-01-0.55.hdf5
#  - 1368s - loss: 0.7798 - binary_accuracy: 0.6906 - val_loss: 0.5461 - val_binary_accuracy: 0.7418
# Epoch 2/100
#
# Epoch 00002: val_loss improved from 0.54609 to 0.51950, saving model to D:/Projects/iSynPro/iSynPro/HilbertCNN/weights/weights-02-0.52.hdf5
#  - 1291s - loss: 0.5525 - binary_accuracy: 0.7271 - val_loss: 0.5195 - val_binary_accuracy: 0.7411
# Epoch 3/100
#
# Epoch 00003: val_loss did not improve
#  - 1290s - loss: 0.5356 - binary_accuracy: 0.7285 - val_loss: 0.5231 - val_binary_accuracy: 0.7303
# Epoch 4/100
#
# Epoch 00004: val_loss did not improve
#  - 1322s - loss: 0.5350 - binary_accuracy: 0.7382 - val_loss: 0.5450 - val_binary_accuracy: 0.7437
# Epoch 5/100
#
# Epoch 00005: val_loss did not improve
#  - 1324s - loss: 0.5244 - binary_accuracy: 0.7408 - val_loss: 0.5271 - val_binary_accuracy: 0.7437
# Epoch 6/100
#
# Epoch 00006: val_loss improved from 0.51950 to 0.51931, saving model to D:/Projects/iSynPro/iSynPro/HilbertCNN/weights/weights-06-0.52.hdf5
#  - 1309s - loss: 0.5214 - binary_accuracy: 0.7425 - val_loss: 0.5193 - val_binary_accuracy: 0.7437
# Epoch 7/100
#
# Epoch 00007: val_loss improved from 0.51931 to 0.50724, saving model to D:/Projects/iSynPro/iSynPro/HilbertCNN/weights/weights-07-0.51.hdf5
#  - 1340s - loss: 0.5200 - binary_accuracy: 0.7448 - val_loss: 0.5072 - val_binary_accuracy: 0.7463
# Epoch 8/100
#
# Epoch 00008: val_loss did not improve
#  - 1343s - loss: 0.5146 - binary_accuracy: 0.7430 - val_loss: 0.5372 - val_binary_accuracy: 0.7504
# Epoch 9/100
#
# Epoch 00009: val_loss improved from 0.50724 to 0.49824, saving model to D:/Projects/iSynPro/iSynPro/HilbertCNN/weights/weights-09-0.50.hdf5
#  - 1317s - loss: 0.5078 - binary_accuracy: 0.7491 - val_loss: 0.4982 - val_binary_accuracy: 0.7483
# Epoch 10/100
#
# Epoch 00010: val_loss did not improve
#  - 1336s - loss: 0.5135 - binary_accuracy: 0.7487 - val_loss: 0.6326 - val_binary_accuracy: 0.7313
# Epoch 11/100
#
# Epoch 00011: val_loss did not improve
#  - 1333s - loss: 0.5155 - binary_accuracy: 0.7519 - val_loss: 0.5845 - val_binary_accuracy: 0.7488
# Epoch 12/100
#
# Epoch 00012: val_loss did not improve
#  - 1339s - loss: 0.5124 - binary_accuracy: 0.7511 - val_loss: 0.6024 - val_binary_accuracy: 0.7349
# Epoch 13/100
#
# Epoch 00013: val_loss improved from 0.49824 to 0.49665, saving model to D:/Projects/iSynPro/iSynPro/HilbertCNN/weights/weights-13-0.50.hdf5
#  - 1325s - loss: 0.5159 - binary_accuracy: 0.7466 - val_loss: 0.4966 - val_binary_accuracy: 0.7478
# Epoch 14/100
#
# Epoch 00014: val_loss did not improve
#  - 1345s - loss: 0.5117 - binary_accuracy: 0.7525 - val_loss: 0.5934 - val_binary_accuracy: 0.7524
# Epoch 15/100
#
# Epoch 00015: val_loss did not improve
#  - 1349s - loss: 0.5155 - binary_accuracy: 0.7518 - val_loss: 0.5291 - val_binary_accuracy: 0.7365
# Epoch 16/100
#
# Epoch 00016: val_loss improved from 0.49665 to 0.49495, saving model to D:/Projects/iSynPro/iSynPro/HilbertCNN/weights/weights-16-0.49.hdf5
#  - 1336s - loss: 0.5101 - binary_accuracy: 0.7517 - val_loss: 0.4949 - val_binary_accuracy: 0.7473
# Epoch 17/100
#
# Epoch 00017: val_loss did not improve
#  - 1329s - loss: 0.5106 - binary_accuracy: 0.7534 - val_loss: 0.5777 - val_binary_accuracy: 0.7359
# Epoch 18/100
#
# Epoch 00018: val_loss did not improve
#  - 1357s - loss: 0.5130 - binary_accuracy: 0.7552 - val_loss: 0.5984 - val_binary_accuracy: 0.7437
# Epoch 19/100
#
# Epoch 00019: val_loss did not improve
#  - 1336s - loss: 0.5085 - binary_accuracy: 0.7556 - val_loss: 0.6246 - val_binary_accuracy: 0.7452
# Epoch 20/100
#
# Epoch 00020: val_loss did not improve
#  - 1314s - loss: 0.5244 - binary_accuracy: 0.7493 - val_loss: 0.7021 - val_binary_accuracy: 0.7463
# Epoch 21/100
#
# Epoch 00021: val_loss did not improve
#  - 1327s - loss: 0.5201 - binary_accuracy: 0.7518 - val_loss: 0.6773 - val_binary_accuracy: 0.7390
# Epoch 22/100
#
# Epoch 00022: val_loss did not improve
#  - 1338s - loss: 0.5150 - binary_accuracy: 0.7550 - val_loss: 0.7660 - val_binary_accuracy: 0.7298
# Epoch 23/100
#
# Epoch 00023: val_loss did not improve
#  - 1330s - loss: 0.5174 - binary_accuracy: 0.7550 - val_loss: 0.5205 - val_binary_accuracy: 0.7488
# Epoch 24/100
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-e4ab99a1110e> in <module>()
#      44                                    validation_steps= test_size // batch_size,
#      45                                    verbose=2,
# ---> 46                                    callbacks = [save_model, csv_logger])
#
# c:\users\wolfgang\anaconda3\envs\tensorflow\lib\site-packages\keras\legacy\interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name +
#      90                               '` call to the Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# c:\users\wolfgang\anaconda3\envs\tensorflow\lib\site-packages\keras\engine\training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    2143                 batch_index = 0
#    2144                 while steps_done < steps_per_epoch:
# -> 2145                     generator_output = next(output_generator)
#    2146
#    2147                     if not hasattr(generator_output, '__len__'):
#
# c:\users\wolfgang\anaconda3\envs\tensorflow\lib\site-packages\keras\utils\data_utils.py in get(self)
#     762                     raise StopIteration()
#     763                 else:
# --> 764                     time.sleep(self.wait_time)
#     765
#     766         # Make sure to rethrow the first exception in the queue, if any
#
# KeyboardInterrupt:
